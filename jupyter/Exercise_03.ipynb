# %% [markdown]
# # Exercise 03: Arbitrary Waveforms
#
# In this exercise, you will try to constrcut an arbitrary waveform from sines/cosines.
#
# Install the necessary packages:

# %%
import sys
# !{sys.executable} -m pip install -U pip
# !{sys.executable} -m pip install -U numpy matplotlib ipywidgets ipympl
# Out:
# Requirement already satisfied: pip in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (24.0)
# Requirement already satisfied: numpy in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (3.8.3)
# Requirement already satisfied: ipywidgets in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (8.1.2)
# Requirement already satisfied: ipympl in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (0.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: comm>=0.1.3 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipywidgets) (8.22.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipywidgets) (5.14.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipywidgets) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipywidgets) (3.0.10)
# Requirement already satisfied: ipython-genutils in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: decorator in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: six>=1.5 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /home/jackie/.pyenv/versions/3.10.13/envs/week8/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)

# %% [markdown]
# and import the needed libraries:

# %%
# %matplotlib widget

import ipywidgets as widgets
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The following code creates an interactive plot:

# %%
def create_plot():
    xs = np.linspace(-10.0,+10.0,1000)

    ys_target = 4*(np.mod(np.ceil((xs-0.2)/4),2) - 0.5)
    ys_sum    = np.zeros_like(ys_target)
    
    fig = plt.figure()
    fig.canvas.toolbar_visible = False
    fig.canvas.resizable       = False
    
    ax  = fig.add_subplot(1, 1, 1)
    ax.set_ylim(-2.5, +2.5)
    plt.xlabel(r'x')
    plt.grid(visible=True, which='major', axis='y')
    
    target_line, = ax.plot(xs, ys_target, color='k', linewidth=5.0)
    sum_line,    = ax.plot(xs, ys_sum,    color='r', linewidth=5.0)

    ax.legend([target_line, sum_line], ['target', 'sum'])
    
    slider_groups = []

    def get_ys(s_a, s_f, s_p):
        return s_a.value * np.sin(s_f.value*xs + s_p.value)
        
    def update_lines(change):
        ys_sum = np.zeros_like(xs)
        for info in slider_groups:            
            s_a, s_f, s_p, line = info[0], info[1], info[2], info[3]
            ys = get_ys(s_a, s_f, s_p)
            line.set_ydata(ys)
            ys_sum += ys
        sum_line.set_ydata(ys_sum)
        fig.canvas.draw_idle()

    def reset_plot(dummy):
        for info in slider_groups:            
            s_a, s_f, s_p = info[0], info[1], info[2]
            s_a.value = 0.0
            s_f.value = 1.0
            s_p.value = 0.0
            
        update_lines('dummy')  
        
    for freq in range(10):
        slider_amp   = widgets.FloatSlider(min=0.0,   max=+3.0,   step=0.01,     value=0.0, description="amp",   continuous_update=True)
        slider_freq  = widgets.FloatSlider(min=0.0,   max=+10.0,   step=0.01,     value=1.0, description="freq",  continuous_update=True)
        slider_phase = widgets.FloatSlider(min=-np.pi, max=+np.pi, step=np.pi/20, value=0.0, description="phase", continuous_update=True)

        line, = ax.plot(xs, get_ys(slider_amp, slider_freq, slider_phase))
        
        slider_amp.observe(update_lines, names='value')
        slider_freq.observe(update_lines, names='value')
        slider_phase.observe(update_lines, names='value')
        slider_groups.append( (slider_amp, slider_freq, slider_phase, line) )
        
    button_reset = widgets.Button(description='reset plot')
    button_reset.on_click(reset_plot)
    
    display(
        widgets.VBox(
            [widgets.HBox([a, f, p]) for a,f,p,l in slider_groups] + [button_reset]
        )
    )
    
create_plot()
# Out:
# VBox(children=(HBox(children=(FloatSlider(value=0.0, description='amp', max=3.0, step=0.01), FloatSlider(value…
# Canvas(resizable=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', '…

# %% [markdown]
# As before, you might want to run this from time to time:

# %%
plt.close('all')

# %% [markdown]
# I have given you a target waveform (a square wave, in bold black)
# to construct, as best you can,
# by summing up to ten sinusoids.
# You can control the amplitudes, frequencies, and phases of the sinusoids.
#
# Initially, all sinusoids have zero amplitude, so the sum (in bold red) will be zero.
#
# As you adjust the sliders,
# each individual sinusoid will be plotted
# in some unique color,
# and the sum (in bold red)
# of all the sinusoids will be updated.
#
# Your goal is to get the red sum
# to match the black target
# as closely as possible.
#
# Note that it is possible to type values into the sliders
# if you're finding it difficult to get the value you want
# with your mouse.
#
# **How well do you think you did?  Would it help to have more frequencies?  Is there a systematic way to adjust the sinusoids?**

# %% [markdown]
# I think I did alright. Having more frequencies would certainly help but if I remember correctly, even an infinite summation of sinusoids would still have those funky edges. But adding more sine waves would get the summed signal closer and closer to the square wave.
#
# There is a systematic way using Fourier expansion! We can divide each amplitude by increasing odd values of n (1, 3, 5, etc.) and since the square wave we are aiming for has an amplitude of 2, we'd multiply the calculated amplitudes by 2 (2/1, 2/3, 2/5, etc.). Next, we can multiply the fundamental frequency by that sinusoid's value of n (1f, 3f, 5f, etc.). I estimated f to be about 0.75 (this is roughly the frequency of the square wave we're trying to match). So, we'd have something like:
# $$2sin(.75x)+(2/3)sin(3*.75x)+(2/5)sin(5*.75x)+...$$

# %% [markdown]
# ![image.png](attachment:4b15958c-6ce8-4453-9640-0d1b88d7b228.png)

# %% [markdown]
# Make sure your final notebook shows your settings so that I can see your final waveform.

# %% [markdown]
# **What did you think of the interactive plots?**

# %% [markdown]
# Amazing! The Euler's was my favorite but all of these really help to fully comprehend these concepts.
